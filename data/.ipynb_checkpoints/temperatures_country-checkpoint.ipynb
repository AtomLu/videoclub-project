# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore') 
import statistics as stats

# %%
temperatures= pd.read_csv("/Users/lcorrea/Documents/GitHub/proyecto ETL/Environment_Temperature.csv",sep=',', encoding='latin-1')

# %%
temperatures
# Out:
#       Area Code         Area  Months Code               Months  Element Code  \
# 0             2  Afghanistan         7001              January          7271
# 1             2  Afghanistan         7001              January          6078
# 2             2  Afghanistan         7002             February          7271
# 3             2  Afghanistan         7002             February          6078
# 4             2  Afghanistan         7003                March          7271
# ...         ...          ...          ...                  ...           ...
# 9651       5873         OECD         7018          JunJulAug          6078
# 9652       5873         OECD         7019          SepOctNov          7271
# 9653       5873         OECD         7019          SepOctNov          6078
# 9654       5873         OECD         7020  Meteorological year          7271
# 9655       5873         OECD         7020  Meteorological year          6078
#
# ...

# %%
temperatures.drop(['Area Code', 'Months Code','Months'], axis=1, inplace = True)

# %%
temperatures
# Out:
#              Area  Element Code             Element Unit  Y1961  Y1962  Y1963  \
# 0     Afghanistan          7271  Temperature change   °C  0.777  0.062  2.744
# 1     Afghanistan          6078  Standard Deviation   °C  1.950  1.950  1.950
# 2     Afghanistan          7271  Temperature change   °C -1.743  2.465  3.919
# 3     Afghanistan          6078  Standard Deviation   °C  2.597  2.597  2.597
# 4     Afghanistan          7271  Temperature change   °C  0.516  1.336  0.403
# ...           ...           ...                 ...  ...    ...    ...    ...
# 9651         OECD          6078  Standard Deviation   °C  0.247  0.247  0.247
# 9652         OECD          7271  Temperature change   °C  0.036  0.461  0.665
# 9653         OECD          6078  Standard Deviation   °C  0.378  0.378  0.378
# 9654         OECD          7271  Temperature change   °C  0.165 -0.009  0.134
# 9655         OECD          6078  Standard Deviation   °C  0.260  0.260  0.260
#
# ...

# %%
temperatures.drop(temperatures[(temperatures['Area'] == 'OECD')].index, inplace=True)

# %%
temperatures.drop(temperatures[(temperatures['Area'] == 'Non-Annex I countries')].index, inplace=True)

temperatures.drop(temperatures[(temperatures['Area'] == 'Annex I countries')].index, inplace=True)

temperatures.drop(temperatures[(temperatures['Area'] == 'Net Food Importing Developing Countries')].index, inplace=True)

temperatures.drop(temperatures[(temperatures['Area'] == 'Low Income Food Deficit Countries')].index, inplace=True)

temperatures.drop(temperatures[(temperatures['Area'] == 'Small Island Developing States')].index, inplace=True)


temperatures.drop(temperatures[(temperatures['Area'] == 'Land Locked Developing Countries')].index, inplace=True)

temperatures.drop(temperatures[(temperatures['Area'] == 'Least Developed Countries')].index, inplace=True)

# %%
temperatures.drop(temperatures[(temperatures['Area'] == 'European Union')].index, inplace=True)

# %%
temperatures.drop(temperatures[(temperatures['Element'] == 'Standard Deviation')].index, inplace=True)

# %%
temperatures
# Out:
#                 Area  Element Code             Element Unit  Y1961  Y1962  \
# 0        Afghanistan          7271  Temperature change   °C  0.777  0.062
# 2        Afghanistan          7271  Temperature change   °C -1.743  2.465
# 4        Afghanistan          7271  Temperature change   °C  0.516  1.336
# 6        Afghanistan          7271  Temperature change   °C -1.709  0.117
# 8        Afghanistan          7271  Temperature change   °C  1.412 -0.092
# ...              ...           ...                 ...  ...    ...    ...
# 9374  European Union          7271  Temperature change   °C  1.400  0.300
# 9376  European Union          7271  Temperature change   °C  1.430 -0.858
# 9378  European Union          7271  Temperature change   °C  0.101 -0.579
# 9380  European Union          7271  Temperature change   °C  1.225  0.174
# 9382  European Union          7271  Temperature change   °C  1.039 -0.241
#
#       Y1963  Y1964  Y1965  Y1966  ...  Y2010  Y2011  Y2012  Y2013  Y2014  \
# ...

# %%
temperatures.drop(['Element Code'], axis=1, inplace = True)

# %%
data_temp = temperatures.apply(lambda row: row[temperatures['Area'].isin(['Bangladesh','China','Vietnam','Pakistan','India','Myanmar'])])

# %%
data_temp
# Out:
#             Area             Element Unit  Y1961  Y1962  Y1963  Y1964  Y1965  \
# 578   Bangladesh  Temperature change   °C  0.928 -1.171 -0.318 -0.268  0.396
# 580   Bangladesh  Temperature change   °C -1.527  0.024  1.319  0.310 -0.417
# 582   Bangladesh  Temperature change   °C  1.024  0.060 -0.066  1.159 -1.184
# 584   Bangladesh  Temperature change   °C  0.813  0.345 -0.855 -0.567 -0.332
# 586   Bangladesh  Temperature change   °C  0.390 -0.233 -1.122 -0.383  0.351
# ...          ...                 ...  ...    ...    ...    ...    ...    ...
# 5634    Pakistan  Temperature change   °C -0.606  0.105  0.828 -0.943  0.041
# 5636    Pakistan  Temperature change   °C -0.250  0.201 -0.464  0.764 -1.625
# 5638    Pakistan  Temperature change   °C  0.078 -0.071  0.638 -0.160 -0.414
# 5640    Pakistan  Temperature change   °C -0.197 -1.175  0.698 -1.084  0.913
# 5642    Pakistan  Temperature change   °C -0.244 -0.235  0.425 -0.356 -0.271
#
# ...

# %%
data_temp.drop(['Y1961', 'Y1962','Y1963','Y1964', 'Y1965','Y1966','Y1967','Y1968', 'Y1969'], axis=1, inplace = True)

# %%
data_temp
# Out:
#             Area             Element Unit  Y1970  Y1971  Y1972  Y1973  Y1974  \
# 578   Bangladesh  Temperature change   °C -0.335  0.095  0.517  0.638 -0.387
# 580   Bangladesh  Temperature change   °C  0.041 -0.654 -2.095  1.214 -0.238
# 582   Bangladesh  Temperature change   °C  0.007 -0.603 -0.079 -0.576 -0.361
# 584   Bangladesh  Temperature change   °C  0.203 -1.625 -0.643  0.965 -0.548
# 586   Bangladesh  Temperature change   °C  0.579 -0.810  0.565 -0.975 -0.526
# ...          ...                 ...  ...    ...    ...    ...    ...    ...
# 5634    Pakistan  Temperature change   °C  0.804 -0.031 -0.967 -0.454 -1.340
# 5636    Pakistan  Temperature change   °C  0.666  1.231 -0.515  0.591  0.992
# 5638    Pakistan  Temperature change   °C  0.547 -0.004 -0.207  0.294  0.073
# 5640    Pakistan  Temperature change   °C  0.411 -0.266 -0.280 -0.083 -0.546
# 5642    Pakistan  Temperature change   °C  0.607  0.233 -0.492  0.087 -0.205
#
# ...

# %%
data_temp.to_csv('temperatures.csv', index = False)
