# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
inventory = pd.read_csv("/Users/lcorrea/Documents/GitHub/w3-database-project/data/inventory.csv",sep=',', encoding='latin-1')

# %%
inventory
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
inventory.drop(columns = ['last_update'])
# Out:
#      inventory_id  film_id  store_id
# 0               1        1         1
# 1               2        1         1
# 2               3        1         1
# 3               4        1         1
# 4               5        1         2
# ..            ...      ...       ...
# 995           996      222         2
# 996           997      222         2
# 997           998      222         2
# 998           999      223         2
# 999          1000      223         2
#
# [1000 rows x 3 columns]

# %%
inventory.to_csv('inventor_y.csv', index = False)
